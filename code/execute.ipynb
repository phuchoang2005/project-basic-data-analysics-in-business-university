# %%
# !python3 random_forest_regression_train.py
# Out:
# /home/code/random_forest_regression_train.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 🔹 Training model for 4185.T...
# ✅ Saved model: models/4185.T_model.pkl
# 🔹 Training model for ACN...
# ✅ Saved model: models/ACN_model.pkl
# 🔹 Training model for AMZN...
# ✅ Saved model: models/AMZN_model.pkl
# 🔹 Training model for BIDU...
# ✅ Saved model: models/BIDU_model.pkl
# 🔹 Training model for GOOG...
# ✅ Saved model: models/GOOG_model.pkl
# 🔹 Training model for IBM...
# ✅ Saved model: models/IBM_model.pkl
# 🔹 Training model for IFX.DE...
# ✅ Saved model: models/IFX.DE_model.pkl
# ...

# %%
# !python3 calculate_expected_return.py
# Out:
# /home/code/calculate_expected_return.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 🔹 Đang xử lý mô hình cho: QUBT
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 🔹 Đang xử lý mô hình cho: MSFT
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 🔹 Đang xử lý mô hình cho: AMZN
# ...
